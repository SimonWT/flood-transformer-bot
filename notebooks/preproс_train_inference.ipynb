# %% [markdown]
# 1. Data
# 2. Model
# 3. Training

# %% [markdown]
# 1. As the data I chosed to went to my course chat data and parse it using https://pypi.org/project/telegram-messages-dump/

# %%
import numpy as np 
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
##Path for data 
PATH = '/content/gdrive/My Drive/datasets/nlp/'
FILE_NAME = 'chat_history.csv'

# %%
train_data = pd.read_csv(PATH + FILE_NAME)

# %%
train_data
# Out:
#       Message Id  ...                                            Message
# 0         558402  ...       Так они все равно пропадают через 2-3 месяца
# 1         558403  ...  Я хожу в магазин (ну в маске) и в ск (верю в т...
# 2         558404  ...                  бля, я думал это я такой ахуевший
# 3         558405  ...  с ковидом иногда позволяю себе забежать по быс...
# 4         558406  ...                                           @mmmsalo
# ...          ...  ...                                                ...
# 9995      568448  ...                                    это не таблетки
# 9996      568449  ...                                                  😑
# 9997      568450  ...                                                NaN
# 9998      568451  ...                               это тоже не таблетки
# 9999      568452  ...                                                  🤡
#
# [10000 rows x 5 columns]

# %%
# !pip install emoji
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.6/dist-packages (0.6.0)

# %%
import re

from nltk.tokenize import WordPunctTokenizer, WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import nltk
import math
import emoji

nltk.download('wordnet')
nltk.download('stopwords')


class Preprocessor:

    def __init__(self):
        self.tokenizer = WordPunctTokenizer()
        self.lemmatizer = WordNetLemmatizer()

    def __call__(self, text):
        result = text
        for preprocessing_func in [self.normalize, self.tokenize, self.lemmatize, self.remove_stop_word]:
            result = preprocessing_func(result)
        return result

    def normalize(self, text): 
        ret = [i for i in re.split('\W', text.lower()) if i.isalpha()]
        ret = ' '.join(ret)
        return ret

    def tokenize(self, text):
        return self.tokenizer.tokenize(text)

    def lemmatize(self, tokens):
        return [self.lemmatizer.lemmatize(token) for token in tokens]

    def remove_stop_word(self, tokens):
        stopWords = set(stopwords.words('russian'))
        return [i for i in tokens if ((i not in stopWords) or (i in emoji.UNICODE_EMOJI))]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
preproc = Preprocessor()
dropedNan = train_data.dropna(subset=["Message"])
preprocessed = dropedNan
preprocessed["Message"] = dropedNan["Message"].apply(lambda a: preproc(a))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
preprocessed["Message"][998]
# Out:
# ['никто',
#  'ебет',
#  'тебе',
#  'мозги',
#  'спокойно',
#  'отдает',
#  'тебе',
#  'справку',
#  'твоими',
#  'оценками',
#  'курса',
#  'уезжешь',
#  'германию']

# %% [markdown]
# Обработали текст: убрали стоп слова, нормализовали, заловеркейсили. Осталось пробежаться по сообщеням и выставить символы окончания строки. И дальше запихнуть это все в языковую модель.

# %%
preprocessed
# Out:
#       Message Id  ...                                            Message
# 0         558402  ...                         [равно, пропадают, месяца]
# 1         558403  ...  [хожу, магазин, маске, ск, верю, сильные, здор...
# 2         558404  ...                        [бля, думал, это, ахуевший]
# 3         558405  ...      [ковидом, позволяю, забежать, быстому, магаз]
# 4         558406  ...                                          [mmmsalo]
# ...          ...  ...                                                ...
# 9994      568447  ...                                          [понимаю]
# 9995      568448  ...                                    [это, таблетки]
# 9996      568449  ...                                                 []
# 9998      568451  ...                                    [это, таблетки]
# 9999      568452  ...                                                 []
#
# [9429 rows x 5 columns]

# %%
from datetime import datetime

# %%
for index, row in preprocessed.iterrows():
  timestamp = datetime.strptime(row["Time"], "%Y-%m-%dT%H:%M:%S+00:00")
  m_id = 567048
  if(row["Message Id"] == m_id):
    print(index, row["Time"], row["Message"], timestamp, type(row["Message Id"]))
    break
# Out:
# 8604 2020-12-15T19:47:58+00:00 ['месте', 'обиделась'] 2020-12-15 19:47:58 <class 'int'>

# %%
test_text = train_data["Message"][81]
test_text
# Out:
# 'понял'

# %% [markdown]
# `<eom>` - word which define end of meaningfull message

# %%
############# EMOJI TRY ##############

# %%
text = u'This is a smiley face \U0001f602'
print(text) # with emoji

emoji_pattern = re.compile(pattern = "["
    u"\U0001F600-\U0001F64F"  # emoticons
    u"\U0001F300-\U0001F5FF"  # symbols & pictographs
    u"\U0001F680-\U0001F6FF"  # transport & map symbols
    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                        "]+", flags = re.UNICODE)
# Out:
# This is a smiley face 😂

# %%
emoji_pattern.match(test_text)

# %%
# !pip install emoji
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.6/dist-packages (0.6.0)

# %%
import emoji

# %%
test_text2 = test_text.split(" ")
test_text2
# Out:
# ['понял']

# %%
emoj = test_text2[-1]
emoj
# Out:
# 'понял'

# %%
test_text2[0] in emoji.UNICODE_EMOJI
# Out:
# False

# %%
############# END EMOJI TRY ##############

# %%
###### ADD SPECIAL SYMBOL FOR END OF MININGFULL MESSAGE

# %%
def get_datetime(string_form_date):
  return datetime.strptime(string_form_date, "%Y-%m-%dT%H:%M:%S+00:00")

# %%
data_eom = preprocessed.copy()

# %%
data_eom = preprocessed.copy()
for index, row in data_eom.iterrows():
  pull = [(index, row)]
  time = get_datetime(row["Time"])
  author = row["Sender Name"]
  mess = row["Message"]
  print(f"[{index}] ({author}): {mess}")
  for j, j_row in data_eom[index:len(data_eom)].iterrows():
    if(len(j_row["Message"]) == 0):
      continue
    j_time =  get_datetime(j_row["Time"])
    j_author = j_row["Sender Name"]
    j_mess = j_row["Message"]
    time_delta = (j_time - time).total_seconds()
    print(f"  -- [{j}] ({j_author}): {j_mess}")
    if (j_author == author and time_delta <= 18):
      last_good_idx = j
      pull.append((j, j_row))
    else:
      index = last_good_idx
      break
  last_idx, last_mess = pull[-1]
  if(len(last_mess["Message"]) > 0 and last_mess["Message"][-1] != "<eom>"):
    data_eom.at[last_idx, 'Message'] = last_mess["Message"] + ["<eom>"]
  # if (index > 10):
  #   break
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   -- [7382] (Qvviko): ['вроде', 'остается']
# [7008] (fatawesome): []
#   -- [7383] (simplearink): ['ребята', 'pai', 'курса', 'объясните', 'па', 'рузге', 'пожалуйста', 'вникаю']
# [7010] (SkarletSkay): ['посылки', 'озона', 'обратно', 'возвращал']
#   -- [7385] (simplearink): ['спасибо']
# [7011] (SkarletSkay): ['энто', 'делать', 'почту']
#   -- [7386] (dmiklashevskaya): ['опечатка', 'видимо']
# [7013] (stupidjava): ['получал', 'вернул', 'деньги']
#   -- [7388] (dmiklashevskaya): ['второе', 'опечатка']
# [7014] (stupidjava): ['жопу', 'оплачивал']
#   -- [7389] (dmiklashevskaya): ['первой', 'строчке', 'опечатка']
# [7015] (N_Flamel): ['оформляешь', 'сайте', 'возврат', 'фоткаешь', 'чё', 'нужно', 'фоткать', 'приносишь', 'почту', 'трекномером', 'который', 'тебе', 'скажут']
#   -- [7390] (simplearink): ['щас']
# [7016] (simplearink): ['общем', 'приложении', 'оформить', 'возврат', 'дадут', 'трек', 'номер', 'идёшь', 'почту', 'говоришь', 'вернуть', 'озон']
#   -- [7391] (simplearink): ['мозг', 'включу']
# [7017] (SkarletSkay): ['бля', 'почте', 'пакеты', 'упаковки']
#   -- [7392] (dmiklashevskaya): ['это', 'пары', 'nслева', 'ходит', 'справа', 'ходит', 'n', 'nесли', 'переместится', 'второй', 'спокойно', 'диагонали', 'перешагнуть']
# [7019] (N_Flamel): ['ага']
#   -- [7394] (simplearink): ['спасибо']
# [7020] (SkarletSkay): ['класс']
#   -- [7396] (BananaAndBread): ['шо', 'приколы', 'качей', 'счастливым', 'чиcлом']
# [7021] (N_Flamel): ['вроде']
#   -- [7396] (BananaAndBread): ['шо', 'приколы', 'качей', 'счастливым', 'чиcлом']
# [7022] (CherryColored): ['упаковку', 'платишь']
#   -- [7397] (BananaAndBread): ['nсчастливые', 'часы', 'cacio', 'e', 'vino', 'nсегодня', 'nбесплатная', 'доставка', 'n', 'n', 'nмы', 'выберем', 'одного', 'счастливчика', 'nкоторый', 'выиграет', 'пиццу', 'барбекю', 'ди', 'поло', 'nдля', 'нужно', 'лишь', 'сделать', 'заказ', 'доставку', 'самовывоз', 'получить', 'код', 'заказа', 'ждать', 'nи', 'верить', 'генератор', 'случайных', 'чисел', 'выберет', 'именно']
# [7023] (SkarletSkay): ['это', 'офк']
#   -- [7398] (BananaAndBread): ['это', 'быстро']
# [7024] (SkarletSkay): ['ребята', 'команда', 'проводит', 'интересное', 'исследование', 'тему', 'олимпиадного', 'неолимпиадного', 'подхода', 'жизни', 'n', 'nэто', 'нужно', 'выявления', 'особенностей', 'усвоения', 'информации', 'подхода', 'обучению', 'просят', 'пройти', 'небольшой', 'опрос', 'минут', 'n', 'nчем', 'человек', 'пройдет', 'давайте', 'заполним', 'анкету', 'ссылке', 'n', 'n', 'nhttps', 'doc', 'google', 'com', 'form', 'd', 'e', 'dglndauwhpfwg', 'viewform']
#   -- [7399] (fatawesome): ['чо', 'ребят', 'сдаём', 'новый', 'технопарк', 'конца', 'года']
# [7025] (jenamax): ['рината', 'берите']
#   -- [7400] (man12102): ['просто', 'главного', 'пожарке', 'назначили']
# [7026] (jenamax): ['we', 'are', 'looking', 'for', 'speaker', 'to', 'meet', 'with', 'iu', 'administration', 'n', 'n', 'we', 've', 'heard', 'your', 'feedback', 'and', 'decided', 'to', 'find', 'a', 'better', 'speaker', 'to', 'negotiate', 'with', 'iu', 'administration', 'n', 'n', 'therefore', 'we', 'are', 'organizing', 'a', 'meeting', 'today', 'in', 'su', 'office', 'if', 'you', 'want', 'to', 'be', 'a', 'speaker', 'attend', 'this', 'meeting', 'show', 'others', 'your', 'skill', 'argument', 'strategy', 'and', 'we', 'will', 'choose', 'the', 'best', 'n', 'n', 'also', 'we', 'will', 'discus', 'our', 'strategy', 'for', 'the', 'friday', 's', 'meeting', 'you', 'can', 'participate', 'via', 'zoom', 'n', 'n', 'we', 'will', 'stream', 'this', 'meeting', 'in', 'zoom', 'so', 'you', 'will', 'be', 'able', 'to', 'vote', 'for', 'the', 'speaker', 'you', 'like', 'via', 'poll', 'in', 'channel', 'so', 'subscribe', 'n', 'n', 'n', 'today', 'pm', 'su', 'office', 'su', 'office', 'is', 'located', 'at', 'floor', 'of', 'dorm', 'n', 'if', 'you', 'would', 'like', 'to', 'attend', 'please', 'write', 'to', 'dimtsaplia', 'n', 'n', 'stay', 'safe']
#   -- [7401] (CherryColored): ['просто', 'тревоги']
# [7027] (AntonovAU): ['опоздает', 'd']
#   -- [7402] (fatawesome): ['ааааааааа']
# [7028] (kamilkoduo): ['ребят', 'подскажите', 'распечатать', 'документы', 'технопарке', 'кажется', 'принтер']
#   -- [7403] (jenamax): ['перенимать', 'передовой', 'опыт', 'общаги']
# [7029] (russab0): []
#   -- [7405] (PRYRAN): ['ебать']
# [7030] (simplearink): ['камне', 'вроде']
#   -- [7407] (DanielFaraday28): ['gorim']
# [7031] (ysukhorukov): ['патиму']
#   -- [7409] (jenamax): ['это', 'новый', 'старый', 'горит']
# [7032] (myaksik): ['россии']
#   -- [7410] (IlnurMIR): ['новый']
# [7033] (ysukhorukov): ['капец']
#   -- [7411] (Mustafin): ['черный', 'дым', 'спец', 'кажется', 'должно']
# [7034] (fatawesome): ['вопроса', 'встречи', 'происходят', 'спикеру', 'нужно', 'самому', 'материал', 'готовить']
#   -- [7412] (mmmsalo): ['куча', 'строй', 'материалов', 'пластика', 'утеплителей']
# [7035] (udntwnme): ['полов', 'гендеров']
#   -- [7413] (indionapolis): ['угли', 'калика']
# [7036] (udntwnme): ['кста', 'столько', 'вопросов', 'охуеют', 'анализировать']
#   -- [7414] (mmmsalo): ['некоторые', 'этажи', 'готовы', 'полностью', 'уборка', 'шла']
# [7037] (Apostrov): ['интерсексуалы', 'ещё']
#   -- [7415] (Mustafin): ['намекаю', 'строят', 'дешмана']
# [7038] (udntwnme): ['паспорту']
#   -- [7416] (mmmsalo): ['дешман']
# [7039] (udntwnme): ['male', 'female']
#   -- [7417] (Mustafin): ['материалы', 'должны', 'гореть']
# [7040] (Apostrov): ['смотря']
#   -- [7418] (mmmsalo): ['твоему', 'проводка', 'утеплитель', 'гореть']
# [7041] (myaksik): []
#   -- [7419] (Mustafin): ['утеплители', 'горят', 'нормальные']
# [7043] (AntAndTim): ['typical', 'arch', 'user']
#   -- [7421] (indionapolis): ['жк', 'вообще', 'пиздос', 'строили']
# [7044] (akhmetbekali): ['это', 'чувак', 'который', 'чат', 'уи', 'писал', 'свой', 'тезис']
#   -- [7422] (Mustafin): ['проводка', 'белым', 'дымом', 'горит', 'стенах']
# [7045] (akhmetbekali): ['сириец']
#   -- [7423] (Mustafin): ['белым', 'горела']
# [7046] (Qvviko): ['сделаешь', 'pacman', 'syu']
#   -- [7424] (Mustafin): ['думаю', 'дома', 'начнут', 'гореть']
# [7047] (rsolovev): ['syyu']
#   -- [7425] (fatawesome): ['нихуя', 'сгоришь']
# [7048] (Qvviko): ['daring', 'today', 'aren', 't', 'we']
#   -- [7426] (mmmsalo): ['чо', 'критично', 'хотя', 'заорёт', 'сигналка', 'выйдут']
# [7050] (ysukhorukov): ['what', 'is', 'this']
#   -- [7428] (Mustafin): ['пизда', 'вчера', 'напугали']
# [7051] (BeLuckyDaf): ['forcefully', 'update', 'local', 'repos', 'and', 'perform', 'upgrade']
#   -- [7429] (Mustafin): ['вишне', 'вышли']
# [7052] (ysukhorukov): ['update', 'upgrade']
#   -- [7430] (Mustafin): ['помню', 'общаге', 'сработала', 'сигнализация', 'пошел', 'эвакуационному', 'выходу', 'закрыт']
# [7054] (BeLuckyDaf): ['типа', 'апдейт', 'сделать', 'любом', 'случае', 'вроде', 'up', 'to', 'date']
#   -- [7433] (ysukhorukov): ['скажи', 'это', 'экструду', 'лол']
# [7055] (BeLuckyDaf): ['if', 'i', 'am', 'not', 'mistaken']
#   -- [7434] (ysukhorukov): ['вакцина', 'гриппа', 'помогает', 'снять', 'симптомы', 'короны']
# [7056] (ysukhorukov): ['проблема']
#   -- [7435] (ysukhorukov): ['this', 'week', 'is', 'the', 'last', 'opportunity', 'to', 'get', 'the', 'flu', 'vaccine', 'the', 'vaccination', 'can', 'be', 'done', 'here', 'on', 'friday', 'n', 'n', 'for', 'this', 'we', 'need', 'to', 'collect', 'the', 'number', 'of', 'applicant', 'please', 'put', 'your', 'name', 'here', 'if', 'you', 'wish', 'to', 'take', 'this', 'vaccine', 'on', 'friday', 'n', 'n', 'vaccination', 'can', 'only', 'be', 'done', 'for', 'citizen', 'of', 'the', 'russian', 'federation', 'this', 'vaccine', 'help', 'to', 'relieve', 'symptom', 'including', 'for', 'coronavirus', 'infection']
# [7057] (BeLuckyDaf): ['проблема']
#   -- [7436] (ysukhorukov): ['это', 'реально', 'работает']
# [7058] (ysukhorukov): ['развалиться', 'херам']
#   -- [7437] (BeLuckyDaf): ['проверь']
# [7059] (ysukhorukov): ['звучит', 'проблема', 'сделать', 'pacman', 'syu']
#   -- [7440] (man12102): ['смотреть', 'звуком']
# [7061] (fenchelfen): ['vvv']
#   -- [7442] (fatawesome): ['камри', 'ехал', 'поди']
# [7062] (fatawesome): ['bitch', 'please']
#   -- [7443] (man12102): ['та', 'это', 'мем', 'тиктока']
# [7063] (vionenv): ['подумой']
#   -- [7444] (man12102): ['голос', 'оттуда', 'взял']
# [7064] (Qvviko): []
#   -- [7445] (fatawesome): ['дык', 'nда']
# [7065] (fatawesome): ['буду', 'звать']
#   -- [7446] (ysukhorukov): ['посаженом', 'тазу']
# [7066] (Qvviko): []
#   -- [7447] (fatawesome): ['шаришь']
# [7067] (fatawesome): []
#   -- [7448] (ysukhorukov): ['видимо']
# [7068] (fatawesome): []
#   -- [7449] (ysukhorukov): ['думал', 'это', 'просто', 'generic', 'шутка', 'хачей', 'которые', 'посаженых', 'тазах', 'гоняют']
# [7069] (Qvviko): []
#   -- [7450] (akhmetbekali): ['notification', 'nзавтра', 'дедлайн', 'квизов', 'англу']
# [7070] (udntwnme): ['чья', 'мама']
#   -- [7451] (vionenv): ['абстракта', 'дедлайн', 'кста']
# [7071] (fatawesome): ['наверно']
#   -- [7452] (ysukhorukov): ['квизы', 'шо']
# [7072] (PRYRAN): ['скольки', 'кухня', 'баре', 'работает']
#   -- [7453] (akhmetbekali): ['квизы']
# [7073] (PRYRAN): ['щас', 'ещё', 'покушать']
#   -- [7454] (ysukhorukov): ['лол']
# [7074] (simplearink): []
#   -- [7455] (fatawesome): ['хочется', 'фронтендера', 'n', 'nвилка', 'nстек', 'вью', 'накст', 'nзадачи', 'выбор', 'n', 'разработка', 'основного', 'продукта', 'компании', 'n', 'инфраструктура', 'фронта', 'используют', 'продуктовые', 'команды', 'уи', 'кит', 'утилитарные', 'пакеты', 'сквозные', 'авторизации', 'т', 'д', 'n', 'n', 'job']
# [7075] (simplearink): ['обычно', 'готовят', 'закрытия']
#   -- [7456] (simplearink): ['бля', 'фронтенд', 'пора']
# [7076] (PRYRAN): ['обычно', 'наоборот', 'час', 'закрытия']
#   -- [7458] (vionenv): ['jo', 'чат']
# [7077] (PRYRAN): ['щас']
#   -- [7459] (simplearink): ['кстати']
# [7078] (PRYRAN): ['админ', 'ответил']
#   -- [7463] (mmmsalo): ['решайся', 'первый', 'неуверенность', 'слышу']
# [7079] (bochkaryoff): ['расписание', 'элективов', 'слд', 'семестр', 'скинуть', 'плез']
#   -- [7463] (mmmsalo): ['решайся', 'первый', 'неуверенность', 'слышу']
# [7080] (rsolovev): ['списка', 'вроде']
#   -- [7463] (mmmsalo): ['решайся', 'первый', 'неуверенность', 'слышу']
# [7081] (BeLuckyDaf): ['здорово', 'снято', 'моё', 'почтение']
#   -- [7463] (mmmsalo): ['решайся', 'первый', 'неуверенность', 'слышу']
# [7082] (BeLuckyDaf): ['enjoy', 'this', 'amazing', 'compilation', 'made', 'from', 'our', 'sport', 'festival', 'see', 'you', 'next', 'year']
#   -- [7464] (vionenv): ['хачу', 'фронтенд']
# [7083] (simplearink): []
#   -- [7465] (gafmn): ['предложишь', 'обучение', 'сперва', 'вероятно', 'многие', 'пойдут']
# [7084] (gafmn): []
#   -- [7466] (vionenv): ['middle', 'n', 'obuchenie']
# [7085] (fatawesome): ['сих', 'пор', 'ищу', 'фронтендера', 'видел', 'n', 'nвилка', 'nстек', 'вью', 'накст', 'nзадачи', 'выбор', 'n', 'разработка', 'основного', 'продукта', 'компании', 'n', 'инфраструктура', 'фронта', 'используют', 'продуктовые', 'команды', 'уи', 'кит', 'утилитарные', 'пакеты', 'сквозные', 'авторизации', 'т', 'д', 'n', 'n', 'job']
#   -- [7467] (simplearink): ['бля', 'пришёл', 'токсик']
# [7087] (myaksik): ['отправляешь', 'диплом', 'супервизору']
#   -- [7469] (vionenv): ['почините', 'фронтенд', 'телеги']
# [7088] (simplearink): ['ахуенно']
#   -- [7470] (mmmsalo): ['токсичу', 'щас']
# [7089] (simplearink): ['соу', 'браун', 'соу', 'вау']
#   -- [7471] (fatawesome): ['оба', 'токсите']
# [7090] (myaksik): ['отдыхаю', 'хули']
#   -- [7472] (fatawesome): ['хорош']
# [7092] (Mustafin): ['норм', 'отдых']
#   -- [7474] (Ortyomka): ['че', 'человека', 'неистовый', 'путь', 'боли', 'страдания', 'подталкиваешь']
# [7093] (anufriyevt): ['кому', 'писать', 'дипломку', 'поменять']
#   -- [7475] (mmmsalo): ['бля', 'посмотрю', 'путь', 'одни', 'одуванчики', 'ромашки', 'никакой', 'боли']
# [7094] (DanielDv99): ['напиши', 'всякий', 'узнаешь']
#   -- [7476] (Ortyomka): ['говорилось', 'одном', 'анеклоте', 'путай', 'туризм', 'эмиграцией']
# [7095] (simplearink): ['напиши', 'личку', 'конкретно', 'такое', 'спрошу', 'завтра']
#   -- [7477] (simplearink): ['мальчики', 'ссорьтесь']
# [7096] (SkarletSkay): ['понимаю']
#   -- [7478] (Ortyomka): ['ссоремся', 'бэке']
# [7097] (SkarletSkay): ['вовремя']
#   -- [7479] (udntwnme): ['оффтоп', 'nвы', 'замечали', 'среднем', 'фронты', 'токсичнее', 'бэк']
# [7098] (SkarletSkay): ['взяла', 'аджаил']
#   -- [7480] (udntwnme): ['никому', 'обиду', 'офк']
# [7099] (SkarletSkay): ['пару', 'часов', 'написала', 'ебланила', 'полсема']
#   -- [7481] (Qvviko): ['выборка', 'одного', 'человека']
# [7100] (myaksik): ['ещё', 'целых', 'полгода']
#   -- [7483] (udntwnme): ['длжно', 'минимум']
# [7101] (SkarletSkay): ['напоминте']
#   -- [7484] (Qvviko): ['каждом', 'классе', 'одному']
# [7102] (SkarletSkay): ['сабмитить']
#   -- [7485] (Qvviko): ['woteva', 'шутка', 'илья', 'токсик']
# [7103] (SkarletSkay): ['ура']
#   -- [7486] (Qvviko): ['смейтесь']
# [7104] (SkarletSkay): ['засабмитила']
#   -- [7487] (simplearink): ['хехехе']
# [7105] (klchanova): ['смены', 'темы', 'диплома', 'n', 'nif', 'there', 'will', 'be', 'any', 'change', 'during', 'the', 'year', 'in', 'thesis', 'topic', 'you', 'should', 'inform', 'doe', 'education', 'innopolis', 'ru', 'or', 'no', 'later', 'than', 'a', 'month', 'before', 'the', 'thesis', 'defense', 'day', 'n', 'n', 'anufriyevt', 'n', 'n', 'висит', 'закрепе', 'чате', 'нашей', 'группы']
#   -- [7489] (Ortyomka): ['ща', 'быканул']
# [7106] (simplearink): ['tnx']
#   -- [7493] (fatawesome): ['детишки']
# [7107] (anufriyevt): []
#   -- [7493] (fatawesome): ['детишки']
# [7108] (anufriyevt): ['спасибо']
#   -- [7496] (Mustafin): ['сисадмины']
# [7109] (anufriyevt): ['защита']
#   -- [7496] (Mustafin): ['сисадмины']
# [7110] (klchanova): ['ясно']
#   -- [7499] (mmmsalo): ['чаво', 'блять']
# [7111] (klchanova): ['июне']
#   -- [7500] (Qvviko): ['турнитин']
# [7112] (anufriyevt): ['значит', 'ещё', 'месяцы']
#   -- [7501] (Qvviko): ['гейм', 'теори']
# [7113] (anufriyevt): []
#   -- [7502] (Qvviko): ['nice']
# [7114] (DanielDv99): ['спасибо']
#   -- [7503] (fatawesome): ['блять', 'свой', 'диплом', 'писать', 'успеваю']
# [7115] (N_Flamel): ['блин', 'сделайте', 'опросик', 'диплому']
#   -- [7504] (fatawesome): ['че', 'доебались']
# [7116] (N_Flamel): ['интересно', 'оно', 'среднее', 'больнице']
#   -- [7505] (Qvviko): ['это', 'неделю']
# [7117] (N_Flamel): ['правда', 'варианты', 'ответа', 'пока', 'могу', 'адекватно', 'придумать', 'прямая', 'градация', 'шла']
#   -- [7506] (mmmsalo): ['пиздец']
# [7118] (mmmsalo): ['спустя', 'часа', 'дедлайна', 'ещё', 'беспокоишься']
#   -- [7507] (mmmsalo): ['неделю', 'какую', 'хуету', 'сделать']
# [7119] (N_Flamel): ['это', 'серьезный', 'дедлайн']
#   -- [7508] (Qvviko): ['слов']
# [7120] (N_Flamel): ['это', 'моему', 'суперу', 'пофиг']
#   -- [7509] (mmmsalo): ['ладно']
# [7121] (mmmsalo): ['знает', 'дедлайне']
#   -- [7510] (mmmsalo): ['думал']
# [7122] (N_Flamel): ['узнал']
#   -- [7512] (SkarletSkay): ['одной', 'англ', 'помогает']
# [7123] (mmmsalo): ['узнал']
#   -- [7513] (fatawesome): ['послезавтра', 'спринт', 'заканчивается', 'начинал', 'делать']
# [7124] (N_Flamel): ['грю', 'залью', 'ссылку', 'оверлиф', 'норм']
#   -- [7515] (fatawesome): ['выходные', 'кутить']
# [7125] (N_Flamel): ['норм']
#   -- [7516] (Qvviko): ['вкусно', 'красиво']
# [7126] (N_Flamel): ['норм', 'особо', 'стараться']
#   -- [7517] (fatawesome): ['английский']
# [7128] (N_Flamel): ['неплох']
#   -- [7519] (Qvviko): ['английский', 'ток', 'начался']
# [7129] (kamilkoduo): ['схватил', 'кернел', 'паник', 'маке']
#   -- [7520] (mmmsalo): ['хотя', 'джавист', 'слов', 'это', 'строчки', 'открывающийся', 'внешний', 'блок']
# [7130] (N_Flamel): ['мак', 'чё', 'последнее', 'время', 'троить', 'начал', 'бывает', 'перепистает', 'реагировать', 'жесты', 'трекпада', 'причины', 'какие', 'окна', 'открывает']
#   -- [7521] (Qvviko): ['асигнмент', 'вроде', 'весит']
# [7131] (N_Flamel): ['вернуть', 'новый', 'попросить']
#   -- [7523] (fatawesome): ['говно']
# [7132] (theMavl): ['прямо', 'стипа', 'отличника']
#   -- [7525] (Qvviko): ['падажжите']
# [7133] (theMavl): ['магазин', 'пятёрочка', 'требуются', 'nпродавец', 'кассир', 'график', 'работы', 'дня', 'дня', 'зарплата', 'руб', 'руб', 'nсборщик', 'заказов', 'график', 'работы', 'рабочих', 'дней', 'выходных', 'зарплата', 'руб', 'руб', 'nтелефон', 'связи', 'директор', 'магазина', 'лейсан']
#   -- [7525] (Qvviko): ['падажжите']
# [7134] (stupidjava): ['учебой', 'совместить']
#   -- [7526] (SkarletSkay): ['itemhandlermanagerfactorybuilderdaotransferloggermanagerimpl']
# [7135] (N_Flamel): ['вообще', 'учиться', 'отлично']
#   -- [7527] (Qvviko): ['типа', 'чужие', 'видим']
# [7137] (DanielFaraday28): ['последнее', 'время', 'уверен', 'вообще', 'учиться']
#   -- [7530] (Qvviko): ['это', 'новый', 'интерфейс', 'наших']
# [7138] (simplearink): ['согласна']
#   -- [7531] (vionenv): ['абстракт', 'своего', 'диплома', 'писать']
# [7139] (CherryColored): ['выучились']
#   -- [7532] (Qvviko): ['write', 'a', 'structured', 'abstract', 'of', 'the', 'provided', 'paper', 'see', 'attached', 'below', 'k', 'hyppnen', 'v', 'm', 'paganuzzi', 'computer', 'science', 'research', 'article', 'the', 'location', 'of', 'different', 'section', 'type', 'and', 'a', 'proposal', 'for', 'standardization', 'in', 'the', 'structure', 'scientometrics']
# [7140] (Qvviko): ['магистратура']
#   -- [7533] (vionenv): ['ок', 'спс']
# [7141] (indionapolis): []
#   -- [7534] (Qvviko): ['буквально', 'прочитать', 'пейпер', 'написать', 'предложения', 'каждому', 'чаптеров']
# [7143] (Qvviko): ['говорил']
#   -- [7537] (fatawesome): ['буквально', 'нахуй']
# [7144] (indionapolis): ['магам', 'резали', 'стипу', 'кста']
#   -- [7538] (Qvviko): ['работы', 'игру', 'бетрейл', 'легаси']
# [7145] (klchanova): []
#   -- [7539] (Qvviko): ['токсичь']
# [7146] (Qvviko): ['теоретические', 'максимумы', 'остались']
#   -- [7540] (Qvviko): ['дают', 'задачу']
# [7147] (Qvviko): []
#   -- [7541] (Qvviko): ['радуйся']
# [7148] (indionapolis): ['это', 'прям', 'зп', 'маке']
#   -- [7543] (SkarletSkay): ['фронт']
# [7149] (indionapolis): []
#   -- [7544] (SkarletSkay): ['выше', 'обсуждали']
# [7151] (klchanova): ['стало', 'n', 'n', 'подписываемся', 'инстаграм']
#   -- [7547] (SkarletSkay): ['влад', 'новые', 'соседи']
# [7152] (indionapolis): ['ох', 'матеша', 'еьаная']
#   -- [7550] (Qvviko): ['dis', 'gu', 'ting']
# [7153] (indionapolis): ['сложна']
#   -- [7553] (simplearink): ['квартиру', 'съехала']
# [7154] (indionapolis): ['спасибо']
#   -- [7555] (simplearink): ['нынче']
# [7155] (mmmsalo): ['вроде', 'итоге', 'максимум', 'остался']
#   -- [7555] (simplearink): ['нынче']
# [7156] (klchanova): ['это', 'старая', 'стата', 'nтогда', 'ещё', 'говорили', 'отличников']
#   -- [7556] (simplearink): ['новые', 'соседи']
# [7157] (klchanova): ['точно']
#   -- [7557] (SkarletSkay): ['этаже', 'выше']
# [7158] (klchanova): ['спасибо', 'сказал', 'nнадо', 'поправить']
#   -- [7558] (simplearink): ['вау']
# [7159] (mmmsalo): ['шарю', 'скипнул', 'митинги', 'слышал', 'примерно']
#   -- [7559] (Qvviko): ['просто', 'съехала', 'прежнего', 'места', 'вместо', 'заселились', 'перваки']
# [7160] (klchanova): ['забыла', 'прост']
#   -- [7561] (simplearink): ['уляля']
# [7161] (bochkaryoff): ['самый', 'максимум']
#   -- [7561] (simplearink): ['уляля']
# [7162] (bochkaryoff): ['самых', 'потных']
#   -- [7562] (myaksik): ['полгода']
# [7163] (mmmsalo): ['максимум', 'изменился']
#   -- [7564] (PRYRAN): ['напомните', 'плез', 'назывался', 'процесс', 'аналог', 'превращали', 'цифру']
# [7164] (mmmsalo): ['экспонента', 'роста', 'оценок', 'увеличилась', 'ещё', 'сильнее']
#   -- [7565] (PRYRAN): ['дискретизация']
# [7165] (bochkaryoff): ['сомневаюсь', 'учиться']
#   -- [7566] (PRYRAN): ['спасибо']
# [7166] (bochkaryoff): ['нужно', 'активным']
#   -- [7567] (harrm): ['обращайся']
# [7167] (N_Flamel): ['ещё', 'стипендию', 'татарстана', 'skarletskay']
#   -- [7568] (harrm): ['рад', 'помочь']
# [7168] (CherryColored): ['сразу']
#   -- [7569] (rsolovev): ['привет', 'nя', 'решила', 'помочь', 'деткам', 'многодетных', 'семей', 'которые', 'отправили', 'письма', 'деду', 'морозу', 'елку', 'желаний', 'nпока', 'взяла', 'письма', 'мальчиков', 'просьбой', 'купить', 'машинку', 'радиоуправлении', 'сумма', 'такая', 'большая', 'своими', 'студенческими', 'возможностями', 'нам', 'нетрудно', 'сплотиться', 'скинуться', 'достаточно', 'n', 'nссылка', 'сбор', 'http', 'www', 'tinkoff', 'ru', 'sl', 'nссылка', 'машинку', 'http', 'www', 'ozon', 'ru', 'context', 'detail', 'id', 'g', 'n', 'np', 's', 'доставку', 'пункта', 'назначения', 'покупку', 'подарков', 'беру', 'хотите', 'подписала', 'открытку', 'вашим', 'именем', 'напишите', 'лс', 'попишитесь', 'перечислении', 'средств', 'дело', 'пойдет', 'буду', 'собирать', 'подарки', 'дальше']
# [7169] (bochkaryoff): ['хотя', 'ебашить', 'ашки', 'писать', 'статьи', 'наверное']
#   -- [7570] (DenisLevkovets): ['сбор', 'завершён', 'отлично']
# [7170] (simplearink): ['сделаем', 'систему', 'которая', 'гибкой', 'уберёт', 'большой', 'разрыв', 'стипендиями', 'похожих', 'оценок', 'n', 'n', 'кстати', 'отличник', 'сема', 'подряд', 'получать', 'сосать']
#   -- [7571] (simplearink): ['хочет', 'таком', 'поучаствовать', 'университете', 'елочка', 'письмами', 'схожу', 'сегодня', 'завтра', 'соберем']
# [7171] (CherryColored): ['года']
#   -- [7572] (udntwnme): ['думаю', 'мб', 'большой', 'сбор', 'сделать', 'нескольким', 'детям', 'игрушки', 'купить', 'каждый', 'создавать']
# [7172] (akhmetbekali): ['никто', 'нашего', 'курса', 'сможет', 'получать', 'следующем', 'семе']
#   -- [7573] (Mustafin): ['хотел', 'видеть', 'копим']
# [7173] (akhmetbekali): ['перваки']
#   -- [7574] (Mustafin): ['списочком']
# [7174] (simplearink): ['почему']
#   -- [7575] (simplearink): ['собрать', 'несколько', 'писем', 'собирать']
# [7175] (mmmsalo): ['самом', 'деле', 'очень', 'имхо', 'самое', 'нечестное', 'новой', 'системе', 'экспонента', 'формуле', 'отрыв', 'отрыв', 'пиздец', 'ебнутый', 'речь', 'вообще']
#   -- [7576] (Nmikriukov): ['знает', 'почему', 'оплата', 'заказа', 'пятерочке', 'мгновенно', 'проходит', 'нажимаю', 'оплатить', 'сразу', 'выводится', 'сообщение', 'успешной', 'оплате', 'пятерочка', 'сбер', 'одном', 'серваке', 'базами', 'хостятся', 'других', 'приложениях', 'пару', 'сек', 'уходит']
# [7176] (akhmetbekali): ['сема', 'подряд']
#   -- [7577] (Mustafin): ['ждут', 'списания', 'делают', 'авторизацию', 'холд', 'наверное']
# [7177] (akhmetbekali): ['считается', 'текущий', 'сем']
#   -- [7578] (BananaAndBread): ['знаю', 'партнеры']
# [7178] (simplearink): []
#   -- [7580] (Mustafin): ['интеграция', 'сложная', 'сделана', 'спрашивают', 'свв']
# [7179] (akhmetbekali): ['следующий']
#   -- [7581] (ionagamed): ['чекают', 'карту', 'привязывании', 'первый', 'привязать', 'списывать', 'угодно']
# [7180] (simplearink): []
#   -- [7582] (Mustafin): ['это', 'сложная', 'большинства']
# [7181] (akhmetbekali): ['осенью', 'учишься']
#   -- [7583] (Mustafin): ['каждой', 'компании', 'одобряют', 'такое', 'стороны', 'банка']
# [7182] (akhmetbekali): ['следующей']
#   -- [7584] (simplearink): ['алла', 'второй', 'сбор', 'открыла', 'дорогую', 'вещь']
# [7183] (simplearink): ['сема', 'подряд']
#   -- [7585] (simplearink): ['те', 'успел', 'сбор', 'машинки', 'n', 'nмальчику', 'инвалиду', 'нужен', 'степпер', 'модель', 'которую', 'указал', 'нету', 'наличии', 'казани', 'складах', 'узнавала', 'эта', 'модель', 'ближайшее', 'время', 'сказали', 'вряд', 'нового', 'года', 'успеет', 'прийти', 'нашла', 'модель', 'получше', 'теми', 'характеристиками', 'встроенный', 'мини', 'компьютер', 'показателями', 'ручки', 'дороже', 'nhttps', 'www', 'ozon', 'ru', 'context', 'detail', 'id', 'advert', 'lv', 'unwymkucdiizqiv', 'h', 'section', 'description', 'offset', 'n', 'nя', 'заранее', 'связалась', 'сначала', 'куратором', 'фонда', 'мамой', 'мальчика', 'уточнения', 'подойдет', 'такая', 'модель', 'сказали', 'ок', 'n', 'nтак', 'незатруднит', 'перевести', 'маленкую', 'сумму', 'велкам', 'http', 'www', 'tinkoff', 'ru', 'sl', 'n', 'np', 's', 'mustafin', 'ваши', 'денежки', 'машинки', 'капнули', 'сбор', 'надеюсь', 'против']
# [7184] (simplearink): []
#   -- [7586] (simplearink): ['смотрите', 'какие', 'прекрасные', 'новости']
# [7185] (akhmetbekali): ['ии']
#   -- [7587] (simplearink): ['яндекс', 'еде', 'появилась', 'доставка', 'роботами', 'курьерами', 'пока', 'воспользоваться', 'одном', 'деловом', 'квартале', 'москвы', 'иннополисе', 'казанью', 'компания', 'собирается', 'расширять', 'зону', 'проекту', 'будут', 'подключаться', 'новые', 'рестораны', 'n', 'nhttps', 'tjournal', 'ru', 'tech']
# [7186] (N_Flamel): ['причем', 'следующая']
#   -- [7588] (simplearink): ['давно', 'инно', 'яндекс', 'еда', 'заработала']
# [7187] (akhmetbekali): ['старые', 'семы', 'считаются']
#   -- [7589] (simplearink): ['бахетле', 'неделе', 'подключились']
# [7188] (akhmetbekali): ['текущий']
#   -- [7590] (simplearink): ['установил', 'приложение', 'действительно', 'n', 'cup', 'cake']
# [7189] (N_Flamel): ['решил']
#   -- [7592] (CherryColored): ['яндекс', 'еду', 'кешбеке', 'выбирать']
# [7190] (simplearink): ['считаются']
#   -- [7593] (Mustafin): ['называется', 'бот', 'еды']
# [7191] (akhmetbekali): ['говорили']
#   -- [7594] (Mustafin): ['потерял']
# [7192] (N_Flamel): ['наоборот']
#   -- [7595] (simplearink): ['superinnobot']
# [7193] (simplearink): ['серочудинов', 'сказал', 'алло']
#   -- [7596] (Mustafin): ['спасибо']
# [7194] (bochkaryoff): ['арины', 'спецом', 'сказали']
#   -- [7597] (PRYRAN): ['яндекс', 'го', 'заказать']
# [7195] (bochkaryoff): []
#   -- [7598] (PRYRAN): ['чот', 'получается']
# [7196] (bochkaryoff): ['чате', 'насколько', 'помню']
#   -- [7599] (PRYRAN): ['бара']
# [7200] (simplearink): ['импоста']
#   -- [7606] (simplearink): ['доставка', 'минут']
# [7201] (akhmetbekali): ['окок']
#   -- [7606] (simplearink): ['доставка', 'минут']
# [7202] (gafmn): ['большая', 'разница', 'отличником', 'получил', 'одну', 'b']
#   -- [7607] (simplearink): ['прокрутки', 'вниз']
# [7203] (bochkaryoff): ['раньше', 'тащемта']
#   -- [7609] (PRYRAN): ['ничо']
# [7204] (mmmsalo): ['ебейшая']
#   -- [7610] (PRYRAN): ['лан']
# [7205] (bochkaryoff): ['получил', 'одну', 'бшку', 'обратно', 'семестра', 'вернешься']
#   -- [7611] (PRYRAN): ['видимо', 'рано']
# [7206] (gafmn): ['равно', 'самом', 'деле']
#   -- [7612] (Picroc): ['показывается', 'жк', 'общаге']
# [7207] (gafmn): ['благо', 'полгода', 'осталось']
#   -- [7613] (simplearink): ['это']
# [7208] (bochkaryoff): []
#   -- [7614] (Picroc): ['адрес', 'доставки', 'общага']
# [7209] (bochkaryoff): ['учитывая', 'нам', 'остался', 'семестр']
#   -- [7615] (Mustafin): ['каве', 'технопарке', 'розетки']
# [7210] (bochkaryoff): ['нам', 'равно']
#   -- [7616] (simplearink): ['охуеть']
# [7211] (gafmn): ['хотя', 'лишними', 'деньги', 'бывают']
#   -- [7618] (myaksik): ['бокам', 'большого', 'стола', 'стоят']
# [7212] (jenamax): ['самом', 'деле', 'логика', 'объяснимая', 'очень', 'часто', 'вообще', 'хера', 'делать', 'попотеть', 'процентов', 'усилий', 'дают', 'процентов', 'результата']
#   -- [7618] (myaksik): ['бокам', 'большого', 'стола', 'стоят']
# [7213] (ysukhorukov): ['получишь', 'nбыть', 'активным', 'учится', 'вещи', 'слабо', 'совместимые', 'nэто', 'возможно', 'сложность', 'получения', 'взлетела', 'просто', 'небес']
#   -- [7619] (Mustafin): ['спасибо']
# [7214] (fatawesome): ['знаешь', 'разница', 'отличником', 'троишником', 'n', 'n', 'троешник', 'счастлив', 'n']
#   -- [7620] (mmmsalo): ['робот', 'умеет', 'никуда', 'ездить', 'кроме', 'жк', 'пока', 'вроде']
# [7216] (simplearink): ['ахахаххахахаха']
#   -- [7623] (PRYRAN): ['катается', 'чилит']
# [7217] (Mustafin): ['макакой']
#   -- [7624] (PRYRAN): ['пока', 'работает']
# [7218] (Mustafin): ['тру']
#   -- [7625] (mmmsalo): ['аа', 'видимо', 'пока', 'учат', 'просто']
# [7219] (myaksik): ['думаю', 'имеется', 'виду', 'обучение', 'универе']
#   -- [7626] (ysukhorukov): ['зимой', 'плохо', 'видели', 'застрявшим', 'снегу']
# [7220] (myaksik): ['тошнит', 'курса', 'нашего']
#   -- [7627] (ysukhorukov): ['косплеил', 'спирита', 'видимо']
# [7221] (myaksik): ['прохожу', 'курсы', 'курсере', 'читаю', 'книжки']
#   -- [7628] (fatawesome): ['ещё', 'очень', 'мемно', 'умеют', 'двумя', 'колёсами', 'заезжать', 'бордюр', 'переворачиваться']
# [7222] (Mustafin): ['универ', 'тебе', 'даёт', 'макакой']
#   -- [7629] (ysukhorukov): ['заниженный', 'слишком']
# [7223] (Mustafin): ['работал', 'udp', 'ретрофит', 'http', 'client', 'умеет', 'работать', 'гуглил', 'везде', 'делается', 'datagramsocket']
#   -- [7630] (Mustafin): ['железка', 'очень', 'похожа', 'эстонскую', 'снега', 'мало']
# [7224] (Mustafin): ['например']
#   -- [7631] (fatawesome): ['очередные', 'инсайды', 'воложа']
# [7225] (myaksik): []
#   -- [7632] (jenamax): ['вывод', 'скорости', 'движения', 'сделал']
# [7226] (myaksik): ['написано', 'последнее', 'время']
#   -- [7633] (Mustafin): ['внешнему', 'виду']
# [7227] (myaksik): ['макаку', 'аргумент', 'считаю', 'недействительным']
#   -- [7636] (Mustafin): ['напоминает']
# [7228] (myaksik): ['пишут', 'стаковерфлоу']
#   -- [7638] (Mustafin): ['хотя', 'немного', 'разные']
# [7229] (myaksik): ['твоя', 'хуйня', 'выполняет', 'запросы', 'поста']
#   -- [7639] (CherryColored): ['хм', 'нам', 'нужна', 'коробка', 'колеса', 'сделать']
# [7230] (ysukhorukov): ['курсы', 'брауна', 'канатова', 'шилова', 'меркина', 'классный', 'чел', 'блин', 'точно', 'дают', 'тебе', 'макакой']
#   -- [7644] (fatawesome): ['нормальная', 'конструкция', 'инженерной', 'точки', 'зрения', 'nмашины', 'четырёх', 'колёсах']
# [7231] (ysukhorukov): ['особенно', 'дс', 'прошлом', 'семестре', 'вместе']
#   -- [7647] (fatawesome): ['тому', 'говоришь', 'мерсе', 'шохе', 'одни', 'железки']
# [7233] (vionenv): ['is', 'it', 'srach', 'pro', 'kursi']
#   -- [7755] (anufriyevt): ['лень', 'искать', 'инфу', 'инвест', 'копилка', 'тиньке', 'граждан', 'рф']
# [7335] (CherryColored): ['просто', 'интересно', 'стало']
#   -- [7758] (anufriyevt): ['кажется', 'пора', 'брать', 'гражданство']
# [7336] (CherryColored): ['напишу']
#   -- [7759] (SkarletSkay): ['http', 'www', 'youtube', 'com', 'watch', 'v', 'obmlbva', 'mxg', 'feature']
# [7339] (Apostrov): ['вопросы', 'ставила', 'просто', 'интреса', 'спрашиваешь']
#   -- [7764] (SkarletSkay): ['ля']
# [7340] (CherryColored): ['пацаны', 'nвот', 'теряем', 'время', 'nможем', 'просто', 'парсить', 'интернет', 'клепать', 'статьи']
#   -- [7765] (SkarletSkay): ['пропустила']
# [7341] (Mustafin): ['вц', 'сто', 'лет', 'обед', 'раньше', 'назывался', 'цукерберг', 'перезвонит']
#   -- [7766] (CherryColored): ['дефчули', 'nго', 'соберёмся', 'будем', 'винкс', 'смотреть']
# [7342] (Mustafin): ['чёт', 'такое']
#   -- [7768] (SkarletSkay): ['го']
# [7343] (DanielFaraday28): ['переживает', 'поводу', 'стипендий']
#   -- [7768] (SkarletSkay): ['го']
# [7344] (DanielFaraday28): ['http', 'www', 'youtube', 'com', 'watch', 'v', 'rg']
#   -- [7769] (CherryColored): ['забились', 'января']
# [7345] (iambackend): ['кого', 'опыт', 'общения', 'поддержкой', 'телеграма']
#   -- [7770] (simplearink): ['go']
# [7346] (iambackend): ['году', 'баг', 'отправил', 'ответили', 'следущие', 'баги', 'отправлял', 'игнорили', 'реально', 'нужна', 'помощь', 'игнорят']
#   -- [7772] (SkarletSkay): ['чур', 'муза']
# [7347] (harrm): ['опенсорсный', 'возьми', 'почини']
#   -- [7773] (SkarletSkay): ['кст', 'черной', 'сделали', 'айшу', 'лейлу', 'мое', 'уважение']
# [7348] (jenamax): ['техподдержки']
#   -- [7774] (CherryColored): ['всем', 'ясно', 'давно', 'рыжей', 'круче', 'nу', 'парень', 'самый', 'красивый']
# [7349] (myaksik): ['человечку', 'нужна', 'помощь', 'проектом', 'nнадо', 'питоне', 'написать', 'проверялку', 'питон', 'проектов', 'плагиат', 'вторника', 'цена', 'nписать']
#   -- [7775] (SkarletSkay): ['канон']
# [7350] (simplearink): ['мунира', 'спросить']
#   -- [7777] (SkarletSkay): ['зато', 'музы', 'самые', 'недеревеяные', 'отношения']
# [7351] (BananaAndBread): ['пользовался', 'опен', 'сурсной', 'хуетой']
#   -- [7781] (SkarletSkay): ['че', 'душу', 'душу', 'живут']
# [7352] (simplearink): ['лох']
#   -- [7781] (SkarletSkay): ['че', 'душу', 'душу', 'живут']
# [7354] (dmiklashevskaya): ['сколько', 'закрывается', 'технопарк', 'скольки', 'забрать', 'посылку', 'постамата', 'озон']
#   -- [7783] (CherryColored): ['стремный', 'nхам']
# [7355] (loaferCH): ['закрывается']
#   -- [7785] (SkarletSkay): ['хотя', 'лейлы', 'прикольно']
# [7356] (klchanova): ['вроде', 'траву', 'зайти']
#   -- [7786] (SkarletSkay): ['вообще', 'имхо', 'самые', 'красивые', 'мальчики', 'другую', 'сторону', 'комнады', 'феечек']
# [7357] (dmiklashevskaya): ['спасибо', 'какие', 'ориентиры', 'постомата', 'рядом', 'банками', 'ещё']
#   -- [7787] (SkarletSkay): ['валтор']
# [7358] (dmiklashevskaya): ['это', 'банки']
#   -- [7788] (gafmn): ['ых', 'nс', 'фобосом', 'сравнения', 'витч']
# [7359] (dmiklashevskaya): ['почта']
#   -- [7789] (SkarletSkay): ['бля', 'фобос', 'это', 'краш']
# [7360] (klchanova): ['это', 'почта']
#   -- [7790] (SkarletSkay): ['вся', 'химия', 'валтером', 'блум']
# [7361] (klchanova): ['ага']
#   -- [7791] (SkarletSkay): ['ухухух']
# [7362] (dmiklashevskaya): ['спасибо', 'кругу', 'найду']
#   -- [7793] (SkarletSkay): ['кисы']
# [7364] (udntwnme): ['озон', 'камне']
#   -- [7795] (myaksik): ['промокод', 'бесплатную', 'доставку']
# [7365] (udntwnme): ['вход', 'камень', 'вроде', 'открыт']
#   -- [7796] (SkarletSkay): ['приложении', 'нори']
# [7366] (ysukhorukov): ['лимит', 'загрузку', 'файлов', 'мудл']
#   -- [7799] (SkarletSkay): ['заказала', 'суши']
# [7367] (N_Flamel): ['подтверждаю', 'справа', 'входа', 'dmiklashevskaya']
#   -- [7799] (SkarletSkay): ['заказала', 'суши']
# [7369] (anufriyevt): ['хочешь', 'использовать', 'облако']
#   -- [7801] (SkarletSkay): ['кончились']
# [7370] (ysukhorukov): ['чекпойнт', 'сетки', 'выгрузить']
#   -- [7803] (gafmn): ['оно', 'стариков', 'инвалидов']
# [7371] (Qvviko): ['вроде', 'определяется', 'создаёт', 'поле', 'сабмита', 'разному']
#   -- [7804] (mmmsalo): ['стипу', 'урезали']
# [7372] (N_Flamel): ['напомните', 'студентикам', 'продлевать', 'лицензию', 'интелиджи']
#   -- [7805] (gafmn): ['ножками', 'сходи']
# [7373] (Mustafin): ['почте', 'пруф']
#   -- [7807] (gafmn): ['хотя', 'зала', 'идёшь', 'особо', 'хочется']
# [7374] (Mustafin): ['запрашивается']
#   -- [7808] (anufriyevt): ['наоборот', 'прилив', 'энерджи']
# [7375] (Mustafin): ['нам', 'почту', 'иннополиса', 'выпуска', 'оставят', 'итоге']
#   -- [7810] (myaksik): ['нормальный']
# [7376] (N_Flamel): ['sps']
#   -- [7810] (myaksik): ['нормальный']
# [7377] (myaksik): ['продлевать', 'жетбрайнс', 'гитхаб']
#   -- [7811] (myaksik): ['пушей', 'пришёл']
# [7378] (myaksik): ['заабузить', 'полученеим', 'диплома', 'продлить', 'ещё', 'год']
#   -- [7813] (myaksik): ['бесплатные', 'доставки']
# [7379] (Mustafin): ['принимать', 'почту']
#   -- [7813] (myaksik): ['бесплатные', 'доставки']
# [7380] (Mustafin): ['отправлять']
#   -- [7814] (gafmn): ['огонь']
# [7381] (myaksik): ['это', 'хз']
#   -- [7815] (gafmn): ['ы', 'видимо', 'спортивный', 'человек', 'просто', 'хочется', 'лечь', 'лицом', 'пол']
# [7382] (Qvviko): ['вроде', 'остается']
#   -- [7816] (myaksik): ['распредлить', 'весь', 'месяц', 'топ']
# [7383] (simplearink): ['ребята', 'pai', 'курса', 'объясните', 'па', 'рузге', 'пожалуйста', 'вникаю']
#   -- [7817] (passgressive): ['неееееетттт', 'сделали', 'флорой', 'блятб']
# [7384] (dmiklashevskaya): ['двигаться', 'свободные', 'клеточки', 'рядом', 'перепрыгивать', 'шашку']
#   -- [7818] (simplearink): ['полненькая']
# [7385] (simplearink): ['спасибо']
#   -- [7822] (udntwnme): ['стоп']
# [7386] (dmiklashevskaya): ['опечатка', 'видимо']
#   -- [7822] (udntwnme): ['стоп']
# [7387] (dmiklashevskaya): []
#   -- [7823] (Ortyomka): ['похавала', 'землю']
# [7388] (dmiklashevskaya): ['второе', 'опечатка']
#   -- [7824] (udntwnme): ['это', 'флора']
# [7389] (dmiklashevskaya): ['первой', 'строчке', 'опечатка']
#   -- [7825] (udntwnme): ['техна']
# [7390] (simplearink): ['щас']
#   -- [7826] (passgressive): ['пойду', 'поплачу']
# ...
# [9716] (Sariell): ['всм']
# [9717] (Sariell): ['ваши', 'предметы']
# [9718] (Sariell): ['сасатб']
# [9719] (Sariell): ['меркин', 'miss', 'me']
# [9720] (fatawesome): ['человека', 'предположили', 'разный', 'набор', 'курсов']
# [9721] (fatawesome): []
# [9722] (fatawesome): ['меркин', 'понятно', 'вроде', 'весело', 'nнадо', 'та', 'поменять']
# [9723] (SkarletSkay): ['кажется', 'предмет', 'каждого', 'цвета']
# [9724] (SkarletSkay): ['соберите', 'треки', 'третьего', 'курса']
# [9725] (Sariell): ['кажется', 'цвета', 'это', 'четверти']
# [9726] (SkarletSkay): []
# [9727] (SkarletSkay): ['это', 'дока', 'взято']
# [9728] (SkarletSkay): ['дисциплин']
# [9729] (Sariell): []
# [9730] (SkarletSkay): ['выглядит']
# [9731] (Sariell): []
# [9732] (SkarletSkay): ['типа', 'блоки', 'предмета', 'выбору']
# [9733] (Sariell): ['вполне', 'возможен', 'вариант', 'какого', 'трека', 'курса', 'одной', 'четверти']
# [9734] (fatawesome): ['видеоразборы', 'фильмов', 'марвел', 'делать']
# [9735] (fatawesome): ['учителями', 'литературы', 'работать']
# [9736] (SkarletSkay): ['видел', 'док', 'понял', 'б']
# [9737] (mmmsalo): ['нихуя', 'непонятно']
# [9738] (mmmsalo): ['очень', 'интересно']
# [9739] (lunacarsky): []
# [9740] (Sariell): []
# [9741] (lunacarsky): ['какие', 'цвета', 'кого']
# [9742] (SkarletSkay): ['треки', 'костыльные']
# [9743] (SkarletSkay): ['набор', 'предметов', 'выбор', 'сета']
# [9744] (mmmsalo): ['дса', 'понятно', 'ору', 'ваших', 'объяснений', 'споров']
# [9745] (ysukhorukov): ['роботикса']
# [9746] (fatawesome): ['этим', 'оттенком', 'коричневого', 'дое', 'хотел', 'передать', 'сложное', 'духовное', 'настроение', 'нависшее', 'университете', 'последний', 'семестр']
# [9747] (rsolovev): ['блоки']
# [9749] (ysukhorukov): ['ага']
# [9750] (SkarletSkay): ['факт']
# [9751] (ysukhorukov): ['фухх', 'проект', 'нормальный', 'сделаем', 'deep', 'dark', 'learning']
# [9752] (ysukhorukov): ['это', 'требуют', 'недели', 'нормальный', 'проект', 'родить']
# [9753] (ysukhorukov): ['такие', 'юзали', 'готовую', 'нейронку', 'офигели']
# [9754] (SkarletSkay): ['бля']
# [9755] (SkarletSkay): ['обещали', 'нормально', 'модульку', 'адаптировать']
# [9757] (ysukhorukov): ['такие', 'неделя', 'midterm', 'delivery', 'офигели']
# [9758] (SkarletSkay): ['типа', 'часть', 'курсов', 'растянуть', 'часть', 'сжать', 'часть', 'оставить']
# [9759] (fatawesome): ['почему', 'никто', 'мемил', 'городецкий', 'гг', 'ночного', 'дозора']
# [9760] (ysukhorukov): ['натрейнить', 'нормально', 'времени', 'дня', 'заняло']
# [9761] (SkarletSkay): ['итоге', 'дое', 'родили', 'хуйню']
# [9762] (fatawesome): ['такого']
# [9763] (Species_decipit): ['сделать', 'срок', 'универе', 'скостили']
# [9764] (ysukhorukov): ['типа', 'курсы', 'брауна', 'это', 'явно', 'сжать', 'причем', 'лекции', 'неделю', 'nпусть', 'задумается', 'лить', 'воду', 'слайды', 'плохая', 'затея']
# [9765] (SkarletSkay): ['нравятся', 'курсы', 'брауна']
# [9766] (fatawesome): ['ведешь', 'плохо']
# [9767] (SkarletSkay): ['визуальные']
# [9768] (SkarletSkay): ['ебут', 'большим', 'колвом', 'инфы']
# [9769] (mmmsalo): ['срок', 'курса', 'пожалуйста']
# [9770] (ysukhorukov): ['ноль', 'полезной', 'инфы', 'лол']
# [9771] (Species_decipit): ['пары', 'ходил']
# [9772] (Species_decipit): ['год', 'полтора', 'назад']
# [9773] (Species_decipit): []
# [9774] (Species_decipit): ['пусть', 'семестр', 'последний', 'отменят']
# [9775] (Species_decipit): ['звучит', 'здорово']
# [9776] (myaksik): []
# [9777] (myaksik): ['билета', 'ещё']
# [9778] (SkarletSkay): ['некоторые', 'попытки', 'преподов', 'дать', 'материал', 'сем', 'выглядят']
# [9779] (ysukhorukov): ['типичный', 'фахим']
# [9780] (Species_decipit): ['тервере', 'чувствовал', 'шилова']
# [9781] (ysukhorukov): ['жиза']
# [9782] (rsolovev): ['дамир']
# [9783] (SkarletSkay): ['пачему', 'студенты', 'могут', 'написать', 'комрехенсив', 'тест']
# [9784] (SkarletSkay): ['почему', 'студенты', 'делают', 'проекты', 'последние', 'дни']
# [9785] (lunacarsky): ['орнул']
# [9787] (SkarletSkay): ['курсы', 'которые', 'дают', 'недельные', 'ассайменты', 'которые', 'занимают', 'времени', 'целый', 'день']
# [9788] (SkarletSkay): ['делайте', 'время', 'семестра', 'проекты', 'ааааааааааааааа']
# [9789] (SkarletSkay): ['извините']
# [9791] (ysukhorukov): ['соссаймента', 'неделю', 'хочешь', 'плюс', 'сверху', 'домашка']
# [9792] (ysukhorukov): ['прожект']
# [9967] (rakhmatullinart): []
# [9968] (rakhmatullinart): []
# [9969] (N_Flamel): []
# [9970] (rakhmatullinart): ['напиши', 'чатик']
# [9971] (mmmsalo): ['просто', 'логин', 'корп', 'почте', 'делаешь']
# [9972] (mmmsalo): []
# [9973] (mmmsalo): ['мс', 'ворде', 'екселе', 'угодно']
# [9974] (N_Flamel): ['ля', 'кул']
# [9975] (N_Flamel): ['спасибо', 'зоопарк', 'помог', 'активировать', 'лицензию']
# [9976] (mmmsalo): ['яж', 'говорю', 'это', 'зоопарк']
# [9977] (indionapolis): []
# [9978] (stupidjava): ['след', 'семе', 'любому', 'бухгалтерия', 'перепутает', 'этими', 'формулами', 'получим', 'залупу', 'будем', 'гореть', 'чатике']
# [9979] (gafmn): []
# [9980] (anufriyevt): []
# [9981] (anufriyevt): []
# [9982] (Onbehalfofme): []
# [9983] (zuhairabbas14): []
# [9984] (fatawesome): []
# [9985] (fatawesome): []
# [9986] (fatawesome): []
# [9987] (fatawesome): []
# [9988] (Sariell): []
# [9989] (kamilkoduo): ['simplearink', 'днем', 'рождения', 'какие', 'таблеточки', 'подарить']
# [9990] (Sariell): ['мескалин']
# [9991] (N_Flamel): ['псилоцибин']
# [9992] (udntwnme): ['пошутила', 'мдма', 'наверное', 'смешно']
# [9993] (N_Flamel): ['пошути', 'диэтиламид', 'd', 'лизергиновой', 'кислоты']
# [9994] (simplearink): ['понимаю']
# [9995] (udntwnme): ['это', 'таблетки']
# [9996] (udntwnme): []
# [9998] (PRYRAN): ['это', 'таблетки']
# [9999] (PRYRAN): []

# %%
data_eom
# Out:
#       Message Id  ...                                            Message
# 0         558402  ...                  [равно, пропадают, месяца, <eom>]
# 1         558403  ...  [хожу, магазин, маске, ск, верю, сильные, здор...
# 2         558404  ...                        [бля, думал, это, ахуевший]
# 3         558405  ...  [ковидом, позволяю, забежать, быстому, магаз, ...
# 4         558406  ...                                   [mmmsalo, <eom>]
# ...          ...  ...                                                ...
# 9994      568447  ...                                   [понимаю, <eom>]
# 9995      568448  ...                             [это, таблетки, <eom>]
# 9996      568449  ...                                                 []
# 9998      568451  ...                             [это, таблетки, <eom>]
# 9999      568452  ...                                                 []
#
# [9429 rows x 5 columns]

# %%
len(data_eom)
# Out:
# 9429

# %%
data_eom[0:10]
# Out:
#    Message Id  ...                                            Message
# 0      558402  ...                  [равно, пропадают, месяца, <eom>]
# 1      558403  ...  [хожу, магазин, маске, ск, верю, сильные, здор...
# 2      558404  ...                        [бля, думал, это, ахуевший]
# 3      558405  ...  [ковидом, позволяю, забежать, быстому, магаз, ...
# 4      558406  ...                                   [mmmsalo, <eom>]
# 5      558407  ...                              [мидихлорианы, <eom>]
# 6      558408  ...                                                 []
# 7      558409  ...                               [эй, ковидом, <eom>]
# 8      558410  ...                                              [всм]
# 9      558411  ...                       [тест, отрицательный, <eom>]
#
# [10 rows x 5 columns]

# %%
##### DICT AND CORPUS

# %%
import os
import torch

class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self):
        self.dictionary = Dictionary()
        # self.train = self.tokenize(os.path.join(path, 'train.txt'))
        # self.valid = self.tokenize(os.path.join(path, 'valid.txt'))
        # self.test = self.tokenize(os.path.join(path, 'test.txt'))

    def tokenize(self, df):
        """Tokenizes a text file."""
        
         # Add words to the dictionary
        tokens = 0
        for idx, row in df.iterrows():
          message = row["Message"]
          if len(message) == 0:
            continue
          tokens += len(message)
          for word in message:
            self.dictionary.add_word(word)

        # Tokenize file content      
        ids = torch.LongTensor(tokens)
        token = 0
        for idx, row in df.iterrows():
          message = row["Message"]
          if len(message) == 0:
            continue
          for word in message:
            ids[token] = self.dictionary.word2idx[word]
            token += 1
        
        return ids

# %%
corpus = Corpus()

# %%
msk = np.random.rand(len(data_eom)) <= 0.7

train_df = data_eom[msk]
val_df = data_eom[~msk]

# %%
train_tokens = corpus.tokenize(train_df)
val_tokens = corpus.tokenize(val_df)

# %%
train_tokens
# Out:
# tensor([    0,     1,     2,  ...,    13, 11427,     3])

# %%
len(train_tokens)
# Out:
# 32949

# %%
##### MODEL ######
import torch.nn as nn

class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, rnn_type, ntoken, ninp, nhid, nlayers, dropout=0.5, tie_weights=False):
        super(RNNModel, self).__init__()
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(ninp, nhid, nlayers, dropout=dropout)
        else:
            try:
                nonlinearity = {'RNN_TANH': 'tanh', 'RNN_RELU': 'relu'}[rnn_type]
            except KeyError:
                raise ValueError( """An invalid option for `--model` was supplied,
                                 options are ['LSTM', 'GRU', 'RNN_TANH' or 'RNN_RELU']""")
            self.rnn = nn.RNN(ninp, nhid, nlayers, nonlinearity=nonlinearity, dropout=dropout)
        self.decoder = nn.Linear(nhid, ntoken)

        # Optionally tie weights as in:
        # "Using the Output Embedding to Improve Language Models" (Press & Wolf 2016)
        # https://arxiv.org/abs/1608.05859
        # and
        # "Tying Word Vectors and Word Classifiers: A Loss Framework for Language Modeling" (Inan et al. 2016)
        # https://arxiv.org/abs/1611.01462
        if tie_weights:
            if nhid != ninp:
                raise ValueError('When using the tied flag, nhid must be equal to emsize')
            self.decoder.weight = self.encoder.weight

        self.init_weights()

        self.rnn_type = rnn_type
        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        if self.rnn_type == 'LSTM':
            return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                    weight.new_zeros(self.nlayers, bsz, self.nhid))
        else:
            return weight.new_zeros(self.nlayers, bsz, self.nhid)

# %%
## Make sure we are using the GPU . Get CUDA device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

batch_size = 4
eval_batch_size = 10
train_data = batchify(train_tokens, batch_size)
val_data = batchify(val_tokens, eval_batch_size)

# %%
import time

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)

def get_batch(source, i):
    seq_len = len(source) - 1 - i
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target
  
def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(eval_batch_size)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output, hidden = model(data, hidden)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
            hidden = repackage_hidden(hidden)
    return total_loss / len(data_source)


def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()

        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        for p in model.parameters():
            p.data.add_(-lr, p.grad.data)

        total_loss += loss.item()

        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // bptt, lr,
                elapsed * 1000 / log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# %%
emsize=650
nhid=650
dropout=0.5
nlayers = 2
ntoken = len(corpus.dictionary)
rnn_type='LSTM'

bptt = 35
log_interval = 10
clip = 0.25
epochs=100

criterion = nn.CrossEntropyLoss()

# %%
model = RNNModel(rnn_type, ntoken, emsize, nhid, nlayers)
model.to(device)
# Out:
# RNNModel(
#   (drop): Dropout(p=0.5, inplace=False)
#   (encoder): Embedding(14560, 650)
#   (rnn): LSTM(650, 650, num_layers=2, dropout=0.5)
#   (decoder): Linear(in_features=650, out_features=14560, bias=True)
# )

# %%
####### TRAINING #########

# Loop over epochs.
lr = 20
best_val_loss = None

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(val_data)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open('weights.pth', 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 4.0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# | epoch   1 |    10/  235 batches | lr 20.00 | ms/batch 3053.59 | loss 14.71 | ppl 2457472.54
# | epoch   1 |    20/  235 batches | lr 20.00 | ms/batch 2641.24 | loss  9.19 | ppl  9804.82
# | epoch   1 |    30/  235 batches | lr 20.00 | ms/batch 2423.29 | loss  8.61 | ppl  5459.71
# | epoch   1 |    40/  235 batches | lr 20.00 | ms/batch 2324.48 | loss  8.68 | ppl  5908.02
# | epoch   5 |   200/  235 batches | lr 0.31 | ms/batch 437.81 | loss  6.42 | ppl   613.83
# | epoch   5 |   210/  235 batches | lr 0.31 | ms/batch 326.86 | loss  6.26 | ppl   522.40
# | epoch   5 |   220/  235 batches | lr 0.31 | ms/batch 223.70 | loss  6.13 | ppl   461.04
# | epoch   5 |   230/  235 batches | lr 0.31 | ms/batch 109.99 | loss  5.81 | ppl   333.75
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 328.87s | valid loss 169.41 | valid ppl 37393651698139151298569746621874222486746818069021828046877844374019899392.00
# -----------------------------------------------------------------------------------------
# | epoch   6 |    10/  235 batches | lr 0.08 | ms/batch 3048.75 | loss  8.48 | ppl  4831.44
# | epoch   6 |    20/  235 batches | lr 0.08 | ms/batch 2596.24 | loss  7.61 | ppl  2013.31
# | epoch   6 |    30/  235 batches | lr 0.08 | ms/batch 2452.76 | loss  7.54 | ppl  1874.36
# | epoch   6 |    40/  235 batches | lr 0.08 | ms/batch 2329.78 | loss  7.49 | ppl  1792.72
# | epoch   6 |    50/  235 batches | lr 0.08 | ms/batch 2217.59 | loss  7.43 | ppl  1693.24
# | epoch   6 |    60/  235 batches | lr 0.08 | ms/batch 2128.08 | loss  7.38 | ppl  1610.63
# | epoch   6 |    70/  235 batches | lr 0.08 | ms/batch 2005.35 | loss  7.35 | ppl  1559.93
# | epoch   6 |    80/  235 batches | lr 0.08 | ms/batch 1838.30 | loss  7.31 | ppl  1496.21
# | epoch   6 |    90/  235 batches | lr 0.08 | ms/batch 1720.23 | loss  7.27 | ppl  1441.72
# | epoch   6 |   100/  235 batches | lr 0.08 | ms/batch 1598.98 | loss  7.23 | ppl  1385.31
# | epoch   6 |   110/  235 batches | lr 0.08 | ms/batch 1477.23 | loss  7.18 | ppl  1310.13
# | epoch   6 |   120/  235 batches | lr 0.08 | ms/batch 1365.98 | loss  7.11 | ppl  1228.60
# | epoch   6 |   130/  235 batches | lr 0.08 | ms/batch 1254.88 | loss  7.04 | ppl  1146.65
# | epoch   6 |   140/  235 batches | lr 0.08 | ms/batch 1136.50 | loss  6.96 | ppl  1053.14
# | epoch   6 |   150/  235 batches | lr 0.08 | ms/batch 1013.90 | loss  6.86 | ppl   950.87
# | epoch   6 |   160/  235 batches | lr 0.08 | ms/batch 882.99 | loss  6.79 | ppl   889.33
# | epoch   6 |   170/  235 batches | lr 0.08 | ms/batch 778.81 | loss  6.73 | ppl   838.72
# | epoch   6 |   180/  235 batches | lr 0.08 | ms/batch 666.78 | loss  6.65 | ppl   775.94
# | epoch   6 |   190/  235 batches | lr 0.08 | ms/batch 548.80 | loss  6.55 | ppl   697.12
# | epoch   6 |   200/  235 batches | lr 0.08 | ms/batch 437.91 | loss  6.39 | ppl   593.29
# | epoch   6 |   210/  235 batches | lr 0.08 | ms/batch 325.04 | loss  6.24 | ppl   513.33
# | epoch   6 |   220/  235 batches | lr 0.08 | ms/batch 223.02 | loss  6.15 | ppl   467.44
# | epoch   6 |   230/  235 batches | lr 0.08 | ms/batch 110.00 | loss  5.89 | ppl   360.55
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 328.59s | valid loss 165.72 | valid ppl 936508310770620395976614164932780476542956723671656723769080915427328000.00
# -----------------------------------------------------------------------------------------
# | epoch   7 |    10/  235 batches | lr 0.02 | ms/batch 3029.62 | loss  8.32 | ppl  4085.79
# | epoch   7 |    20/  235 batches | lr 0.02 | ms/batch 2598.62 | loss  7.51 | ppl  1819.28
# | epoch   7 |    30/  235 batches | lr 0.02 | ms/batch 2454.45 | loss  7.47 | ppl  1758.01
# | epoch   7 |    40/  235 batches | lr 0.02 | ms/batch 2337.97 | loss  7.45 | ppl  1723.57
# | epoch   7 |    50/  235 batches | lr 0.02 | ms/batch 2218.13 | loss  7.41 | ppl  1652.97
# | epoch   7 |    60/  235 batches | lr 0.02 | ms/batch 2134.62 | loss  7.37 | ppl  1587.67
# | epoch   7 |    70/  235 batches | lr 0.02 | ms/batch 2004.37 | loss  7.35 | ppl  1553.94
# | epoch   7 |    80/  235 batches | lr 0.02 | ms/batch 1845.64 | loss  7.31 | ppl  1498.90
# | epoch   7 |    90/  235 batches | lr 0.02 | ms/batch 1714.91 | loss  7.28 | ppl  1447.83
# | epoch   7 |   100/  235 batches | lr 0.02 | ms/batch 1603.52 | loss  7.24 | ppl  1393.67
# | epoch   7 |   110/  235 batches | lr 0.02 | ms/batch 1479.87 | loss  7.18 | ppl  1317.18
# | epoch   7 |   120/  235 batches | lr 0.02 | ms/batch 1366.61 | loss  7.12 | ppl  1230.65
# | epoch   7 |   130/  235 batches | lr 0.02 | ms/batch 1256.50 | loss  7.04 | ppl  1147.07
# | epoch   7 |   140/  235 batches | lr 0.02 | ms/batch 1137.58 | loss  6.96 | ppl  1049.09
# | epoch   7 |   150/  235 batches | lr 0.02 | ms/batch 1015.68 | loss  6.85 | ppl   944.83
# | epoch   7 |   160/  235 batches | lr 0.02 | ms/batch 882.02 | loss  6.78 | ppl   881.83
# | epoch   7 |   170/  235 batches | lr 0.02 | ms/batch 781.69 | loss  6.72 | ppl   827.79
# | epoch   7 |   180/  235 batches | lr 0.02 | ms/batch 667.83 | loss  6.64 | ppl   765.53
# | epoch   7 |   190/  235 batches | lr 0.02 | ms/batch 549.58 | loss  6.53 | ppl   684.11
# | epoch   7 |   200/  235 batches | lr 0.02 | ms/batch 436.43 | loss  6.37 | ppl   584.61
# | epoch   7 |   210/  235 batches | lr 0.02 | ms/batch 324.61 | loss  6.23 | ppl   508.28
# | epoch   7 |   220/  235 batches | lr 0.02 | ms/batch 223.72 | loss  6.15 | ppl   469.23
# | epoch   7 |   230/  235 batches | lr 0.02 | ms/batch 110.37 | loss  5.94 | ppl   378.22
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 328.73s | valid loss 164.60 | valid ppl 304537421408217578489090623065922485201209732544351159336151048748269568.00
# -----------------------------------------------------------------------------------------
# | epoch   8 |    10/  235 batches | lr 0.00 | ms/batch 3037.99 | loss  8.26 | ppl  3875.12
# | epoch   8 |    20/  235 batches | lr 0.00 | ms/batch 2598.50 | loss  7.47 | ppl  1754.94
# | epoch   8 |    30/  235 batches | lr 0.00 | ms/batch 2455.42 | loss  7.44 | ppl  1705.31
# | epoch   8 |    40/  235 batches | lr 0.00 | ms/batch 2336.52 | loss  7.43 | ppl  1682.95
# -----------------------------------------------------------------------------------------
# Exiting from training early

# %%
model.eval()
# Out:
# RNNModel(
#   (drop): Dropout(p=0.5, inplace=False)
#   (encoder): Embedding(14560, 650)
#   (rnn): LSTM(650, 650, num_layers=2, dropout=0.5)
#   (decoder): Linear(in_features=650, out_features=14560, bias=True)
# )

# %%
##### Inference ######

# %%
messages = ["привет", "не подскажешь", "где найти принтер?"]
dfs = [pd.DataFrame([msg], columns =['Message']) for msg in messages] 
for df in dfs:
  df["Message"] = df["Message"].apply(lambda a: preproc(a))

# %%
msg_tensors = [corpus.tokenize(df) for df in dfs]
msg_tensors
# Out:
# [tensor([147]), tensor([14573]), tensor([2294, 8696])]

# %%
for idx, token_tensor in enumerate(msg_tensors):
  msg_tensors[idx] = token_tensor.to(device)

# %%
def generate_text_from_tensor(token_tensor, target_length, temperature):
    """Sampling from the softmax distribution."""    
    hidden = model.init_hidden(1)
    _, hidden = model(token_tensor[:-1].unsqueeze(1), hidden)
    input_tensor = torch.zeros((1, 1)).long().to(device)
    input_tensor[0, 0].fill_(token_tensor[-1])
    res = []
    with torch.no_grad():    
        for i in range(target_length):            
            output, hidden = model(input_tensor, hidden)
            word_weights = output.squeeze().div(temperature).exp()
            word_idx = torch.multinomial(word_weights, 1)[0]
            input_tensor[0, 0].fill_(word_idx)
            res.append(word_idx.item())
    return [
        [
           corpus.dictionary.idx2word[x] for x in arr            
        ] for arr in (token_tensor.numpy(), res)
    ]

# %%
msg_tensors[0].dtype
# Out:
# torch.int64

# %%
train_data[0]
# Out:
# tensor([   0,  279,  260, 9055], device='cuda:0')

# %%
hidden = model.init_hidden(4)
data, targets = get_batch(train_data, 0)
# print(data[:][0].size())
hidden = repackage_hidden(hidden)
# model.zero_grad()
output, hidden = model(data, hidden)
# _, hidden = model(train_data[0][:-1], hidden)

# %%
word_weights = output.squeeze().div(20).exp()
word_idx = torch.multinomial(word_weights[0], 1)[0]
# input_tensor[0, 0].fill_(word_idx)
print(word_idx.item())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-169-7f6b030a7b97> in <module>()
# ----> 1 word_weights = output.squeeze().div(20).exp()
#       2 word_idx = torch.multinomial(word_weights[0], 1)[0]
#       3 # input_tensor[0, 0].fill_(word_idx)
#       4 print(word_idx.item())
#
# RuntimeError: CUDA out of memory. Tried to allocate 1.79 GiB (GPU 0; 14.73 GiB total capacity; 11.39 GiB already allocated; 1.65 GiB free; 12.15 GiB reserved in total by PyTorch)

# %%
corpus.dictionary.idx2word[word_idx.item()]
# Out:
# 'порешал'

# %%
model.eval()
# Out:
# RNNModel(
#   (drop): Dropout(p=0.5, inplace=False)
#   (encoder): Embedding(14560, 650)
#   (rnn): LSTM(650, 650, num_layers=2, dropout=0.5)
#   (decoder): Linear(in_features=650, out_features=14560, bias=True)
# )
